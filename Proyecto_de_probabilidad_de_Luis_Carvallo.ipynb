# %% [markdown]
# Ejercicio 1
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random


iteraciones = 1000
exitos = 0

# Ejecutar el experimento 1000 veces
for i in range(iteraciones):
    # Lanzar dos dados (números del 1 al 6)
    dado1 = random.randint(1, 6)
    dado2 = random.randint(1, 6)

    suma = dado1 + dado2

    # Comprobar las condiciones
    if suma > 7 or suma % 2 == 0:
        exitos += 1


probabilidad_estimada = exitos / iteraciones

print(f"Total de éxitos: {exitos}")
print(f"Probabilidad estimada: {probabilidad_estimada}")
# Out:
# Total de éxitos: 646
# Probabilidad estimada: 0.646

# %% [markdown]
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# Tomar 3 blancas y 2 rojas.
# Toas todas del mismo color.
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import random #Necesite ayuda para este

# 1. Crear la caja con las bolas usando tu lógica de diccionario
ball_box = {}
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"


iteraciones = 1000
exitos_3w_2r = 0
exitos_mismo_color = 0

for _ in range(iteraciones):
    mano = []

    for _ in range(5):
        # Generamos un índice aleatorio entre 0 y 59
        indice_azar = random.randint(0, 59)
        mano.append(ball_box[indice_azar])

    # Conteo de colores en la mano actual
    blancas = mano.count("White")
    rojas = mano.count("Red")
    verdes = mano.count("Green")

    # Condición 1: Tomar 3 blancas y 2 rojas
    if blancas == 3 and rojas == 2:
        exitos_3w_2r += 1

    # Condición 2: Todas del mismo color (5 blancas, 5 rojas o 5 verdes)
    if blancas == 5 or rojas == 5 or verdes == 5:
        exitos_mismo_color += 1

# 3. Cálculo de probabilidades estimadas
prob_3w_2r = exitos_3w_2r / iteraciones
prob_mismo_color = exitos_mismo_color / iteraciones

print(f"--- Resultados tras {iteraciones} experimentos ---")
print(f"Probabilidad estimada (3 Blancas, 2 Rojas): {prob_3w_2r}")
print(f"Probabilidad estimada (Mismo color): {prob_mismo_color}")
# Out:
# --- Resultados tras 1000 experimentos ---
# Probabilidad estimada (3 Blancas, 2 Rojas): 0.002
# Probabilidad estimada (Mismo color): 0.031

# %% [markdown]
# *   PARA RESOLVER EN CLASE:
# 1. Qué es combinatoria, permutación y como esto se relaciona con probabilidad.
# 1.1. Diferencia entre en combinatoria o permutación.
# 2.  Un entrenador dispone de 22 jugadores para formar un equipo de fútbol.
# ¿Cuántas alineaciones de 11 jugadores puede hacer?
# 3. ¿Cuántas opciones tienes, si debes escoger tres asignaturas entre seis
# optativas?
# 4. ¿De cuántas formas se pueden sentar tres personas en seis sillas?.
# 5. ¿Cuántas jugadas diferentes se pueden obtener si se sacan cinco cartas de una
# baraja de 40 cartas?
# 6. ¿De cuántas formas se pueden sentar cinco personas en una fila de butacas de
# un cine?
# *   Elemento de lista

# %% [markdown]
# Que es una combinatoria, permutación y como esto se relaciona con probabilidad.
#
# Combinatoria:
# Rama de las matemáticas que estudia las técnicas para contar, organizar y seleccionar elementos bajo ciertas reglas.
#
# Permutación:
# Forma de ordenar elementos donde el orden importa. Cada orden distinto cuenta como un resultado diferente.
#
# Combinación:
# Forma de seleccionar elementos donde el orden no importa. Solo interesa qué elementos se eligen, no cómo se acomodan.
#
# Probabilidad:
# Medida numérica que expresa la posibilidad de que ocurra un evento, calculada como la razón entre casos favorables y casos posibles

# %% [markdown]
# Diferencia entre combinatoria o permutacion
#
# Combinatoria → Es el campo general que estudia técnicas de conteo.
#
# Permutación → Es una herramienta de la combinatoria para contar ordenamientos.

# %%
import numpy as np
jugadores = 22
alineacion = 11

numerador = np.prod(np.arange(jugadores - alineacion + 1, jugadores + 1))
# Calculamos el denominador (factorial de 11)
denominador = np.prod(np.arange(1, alineacion + 1))

# El resultado final
combinaciones = numerador / denominador

print(f"Combinaciones posibles: {int(combinaciones)}")
# Out:
# Combinaciones posibles: 705432

# %%
import numpy as np
optativas = 6
materias_elegidas = 3

numerador = np.prod(np.arange(optativas - materias_elegidas + 1, optativas + 1))
# Calculamos el denominador (factorial de 11)
denominador = np.prod(np.arange(1, materias_elegidas + 1))

# El resultado final
combinaciones = numerador / denominador

print(f"Combinaciones posibles: {int(combinaciones)}")
# Out:
# Combinaciones posibles: 20

# %%
n = 6
k = 3

resultado = 1
for i in range(k):
    resultado *= (n - i)

print(f"Permutaciones (n={n}, k={k}): {resultado}")
# Out:
# Permutaciones (n=6, k=3): 120

# %%
import numpy as np
cartas = 40
jugadas = 5

numerador = np.prod(np.arange(cartas - jugadas + 1, cartas + 1))
# Calculamos el denominador (factorial de 11)
denominador = np.prod(np.arange(1, jugadas + 1))

# El resultado final
combinaciones = numerador / denominador

print(f"Combinaciones posibles: {int(combinaciones)}")
# Out:
# Combinaciones posibles: 658008

# %%
personas = 5
resultado = 1
n = personas

while n > 0:
    resultado *= n
    n -= 1

print(f"Las {personas} personas se pueden sentar de {resultado} formas.")
# Out:
# Las 5 personas se pueden sentar de 120 formas.

# %%
from scipy.special import comb, factorial
n_operativas = 6
n = 3
opciones2 = comb(n_operativas, n)
opciones2
# Out:
# np.float64(20.0)

# %%
import math
n, k = 22, 11
alineaciones = math.factorial(n) // (math.factorial(k) * math.factorial(n - k))
print(alineaciones)
# Out:
# 705432

# %%
#EJERCICIO IV. - VERSION II
import itertools
formas = len(list(itertools.permutations(range(6), 3)))
print(formas)
# Out:
# 120

# %%
#PERMUTACIONES GENERADAS
list(itertools.permutations(range(6), 3))
# Out:
# [(0, 1, 2),
#  (0, 1, 3),
#  (0, 1, 4),
#  (0, 1, 5),
#  (0, 2, 1),
#  (0, 2, 3),
#  (0, 2, 4),
#  (0, 2, 5),
#  (0, 3, 1),
#  (0, 3, 2),
#  (0, 3, 4),
#  (0, 3, 5),
#  (0, 4, 1),
#  (0, 4, 2),
#  (0, 4, 3),
#  (0, 4, 5),
#  (0, 5, 1),
#  (0, 5, 2),
#  (0, 5, 3),
#  (0, 5, 4),
#  (1, 0, 2),
#  (1, 0, 3),
#  (1, 0, 4),
#  (1, 0, 5),
#  (1, 2, 0),
#  (1, 2, 3),
#  (1, 2, 4),
#  (1, 2, 5),
#  (1, 3, 0),
#  (1, 3, 2),
#  (1, 3, 4),
#  (1, 3, 5),
#  (1, 4, 0),
#  (1, 4, 2),
#  (1, 4, 3),
#  (1, 4, 5),
#  (1, 5, 0),
#  (1, 5, 2),
#  (1, 5, 3),
#  (1, 5, 4),
#  (2, 0, 1),
#  (2, 0, 3),
#  (2, 0, 4),
#  (2, 0, 5),
#  (2, 1, 0),
#  (2, 1, 3),
#  (2, 1, 4),
#  (2, 1, 5),
#  (2, 3, 0),
#  (2, 3, 1),
#  (2, 3, 4),
#  (2, 3, 5),
#  (2, 4, 0),
#  (2, 4, 1),
#  (2, 4, 3),
#  (2, 4, 5),
#  (2, 5, 0),
#  (2, 5, 1),
#  (2, 5, 3),
#  (2, 5, 4),
#  (3, 0, 1),
#  (3, 0, 2),
#  (3, 0, 4),
#  (3, 0, 5),
#  (3, 1, 0),
#  (3, 1, 2),
#  (3, 1, 4),
#  (3, 1, 5),
#  (3, 2, 0),
#  (3, 2, 1),
#  (3, 2, 4),
# ...
